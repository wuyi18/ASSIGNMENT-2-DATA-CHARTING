# %%
import numpy as np
import matplotlib.pyplot as plt

N = 37

male = {1490858, 1668970, 2058871, 2191195, 2455135, 894882, 2235424, 2200834, 1518838, 2165547, 1141769, 1694147, 1261990, 1717352, 1245392, 2068192, 2289555, 3212840, 4955520, 3048917, 1713128, 1741635, 1243068, 4799078, 982417, 2086689, 1977266, 1818801, 1799316, 2944693, 1680086, 2743041, 1945874, 1204785, 1226052, 1726602, 787080}


ind = np.arange(N)
width = 0.9


p = plt.bar(ind, male, width, color = "#4CAF50")


plt.ylabel("Population")
plt.title("MALE POPULATION FORECAST 2007")
plt.xticks(ind, {"Abia", "Adamawa", "Akwa Ibom", "Anambra", "Bauchi", "Bayelsa", "Benue", "Borno", "Cross River", "Delta", "Ebonyi", "Edo", "Ekiti", "Enugu", "Gombe", "Imo", "Jigawa", "Kaduna", "Kano", "Katsina", "Kebbi", "Kogi", "Kwara", "Lagos", "Nasarawa", "Niger", "Ogun", "Ondo", "Osun", "Oyo", "Plateau", "Rivers", "Sokoto", "Taraba", "Yobe", "Zamfara", "FCT Abuja"}, rotation = 90)


plt.show()

# %%
N = 37

female = {1432393, 1603520, 1978131, 2105266, 2358855, 859788, 2147760, 2114526, 1459275, 2080624, 1096994, 1627710, 1212500, 1650005, 1196553, 1987086, 2199768, 3086847, 4761186, 2929352, 1645947, 1673336, 1194320, 4610879, 943891, 2004858, 1899726, 1747475, 1728754, 2829214, 1614200, 2635471, 1869565, 1157539, 1177972, 1658892, 756214}
ind = np.arange(N)
width = 0.9

p = plt.bar(ind, female, width, color = "black")

plt.ylabel("Population")
plt.title("FEMALE POPULATION FORECAST 2007")
plt.xticks(ind, {"Abia", "Adamawa", "Akwa Ibom", "Anambra", "Bauchi", "Bayelsa", "Benue", "Borno", "Cross River", "Delta", "Ebonyi", "Edo", "Ekiti", "Enugu", "Gombe", "Imo", "Jigawa", "Kaduna", "Kano", "Katsina", "Kebbi", "Kogi", "Kwara", "Lagos", "Nasarawa", "Niger", "Ogun", "Ondo", "Osun", "Oyo", "Plateau", "Rivers", "Sokoto", "Taraba", "Yobe", "Zamfara", "FCT Abuja"}, rotation = 90)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 37

TOTAL = {2923252, 3272489, 4037002, 4296460, 4813990, 1754670, 4383184, 4315360, 2978113, 4246171, 2238763, 3321856, 2474489, 3367357, 2441945, 4055278, 4489323, 6299687, 9716706, 5978269, 3359075, 3414971, 2437389, 9409957, 1926308, 4091546, 3876993, 3566276, 3528070, 5773907, 3294287, 5378512, 3815439, 2362324, 2404024, 3385494, 1543293}


ind = np.arange(N)
width = 0.9


p = plt.bar(ind, TOTAL, width, color = "yellow")


plt.ylabel("Total Population")
plt.title("TOTAL POPULATION FORECAST FOR 2007")
plt.xticks(ind, {"Abia", "Adamawa", "Akwa Ibom", "Anambra", "Bauchi", "Bayelsa", "Benue", "Borno", "Cross River", "Delta", "Ebonyi", "Edo", "Ekiti", "Enugu", "Gombe", "Imo", "Jigawa", "Kaduna", "Kano", "Katsina", "Kebbi", "Kogi", "Kwara", "Lagos", "Nasarawa", "Niger", "Ogun", "Ondo", "Osun", "Oyo", "Plateau", "Rivers", "Sokoto", "Taraba", "Yobe", "Zamfara", "FCT Abuja"}, rotation = 90)


plt.show()
